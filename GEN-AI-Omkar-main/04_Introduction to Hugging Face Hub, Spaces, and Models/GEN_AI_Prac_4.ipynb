# %%
! pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...

# %%
from datasets import load_dataset

# %%
dataset= load_dataset("CopyleftCultivars/SemiSynthetic_Composting_Knowledge_For_Agriculture")
# Out:
# ...
# Generating train split:   0%|          | 0/51 [00:00<?, ? examples/s]

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['Steps', 'Method', 'Ingredients'],
#     num_rows: 51
# })

# %%
dataset['train'].to_pandas()
# Out:
#                                                 Steps  \
# 0   [Layer green waste, manure, and brown waste in...
# 1   [Set up a worm bin with bedding material at th...
# 2   [Layer kitchen scraps and manure in a Bokashi ...
# 3   [Mix manure with green and brown waste in a la...
# 4   [Start with a layer of cardboard or newspaper ...
# 5   [Dig a trench about 12 inches deep in your gar...
# 6   [Build a large pile with manure, green waste, ...
# 7   [Bury a large PVC pipe or similar container wi...
# 8   [Dig a trench or simply start on the ground., ...
# 9   [Mix biochar with manure, kitchen scraps, and ...
# 10  [Fill a bucket with water and add a few handfu...
# 11  [Layer kitchen scraps and manure in a Bokashi ...
# 12  [Select ripe fruits, chop them into small piec...
# 13  [Chop the herbs and mix them with brown sugar ...
# 14  [Clean and dry eggshells, then crush them into...
# 15  [Clean and dry animal bones, then crush them i...
# ...

# %%
converted =load_dataset("csv", data_files='/content/sample_data/california_housing_test.csv')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
converted
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value'],
#         num_rows: 3000
#     })
# })
